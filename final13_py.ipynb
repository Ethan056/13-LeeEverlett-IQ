# %% [markdown]
# <a href="https://colab.research.google.com/github/Ethan056/13-LeeEverlett-IQ/blob/main/final13_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello! Welcome to Age Program!")
print("I'm Sinlapachai Nantaphan M.4/4 No.13")

Year = input("\nWhat year were you born? : ")
DOB = 2026 - int(Year)
print(f"Your Age is {DOB} years old!")
# Out:
# Hello! Welcome to Age Program!
# I'm Sinlapachai Nantaphan M.4/4 No.13
#
# What year were you born? : 2009
# Your Age is 17 years old!
