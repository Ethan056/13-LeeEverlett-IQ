# %% [markdown]
# <a href="https://colab.research.google.com/github/Ethan056/13-LeeEverlett-IQ/blob/main/mid_13_IQ_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #สอบกลางภาค

# %%
print("โปรแกรมหาค่าความเร่ง")
V1 = float(input("\nโปรดระบุค่า V.1 : "))
V2 = float(input("โปรดระบุค่า V.2 : "))
Time = int(input("ระบุเวลา (จำนวนเต็มบวก) : "))

Result = (V2 - V1)/Time
print("\nความเร่งมีค่าเท่ากับ : ", Result ,"m/s^2")
print("\nจัดทำโดย นายศิลปชัย นันทะพันธ์ ม.4/4 เลขที่ 13 ชื่อเล่น ไอคิวครับ 💕")
# Out:
# โปรแกรมหาค่าความเร่ง
#
# โปรดระบุค่า V.1 : 10
